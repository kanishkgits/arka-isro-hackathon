# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import LogNorm
import numpy as np

# %%
import sys
import os
sys.path.append(os.path.abspath('../Scripts'))

import Bulkparameters
import TH_parameters 
from cactusHandler import parse_cactus_file

# %%
BLK_FILE = '../data/BLK/*.cdf'
TH1_FILE = '../data/TH1/*.cdf'
INVALID = -1e31

# %%
BLKdata = Bulkparameters.load_blk_variables(BLK_FILE, INVALID)
thtime, energy, flux = TH_parameters.loadfiles(TH1_FILE)

# %%
filtered_cme_times = parse_cactus_file("../data/cmecat.txt")

# %%
plt.figure(figsize=(20, 5)) 

# Plot number density
plt.plot(BLKdata['time'], BLKdata['proton_density'], label='Proton Density', linewidth = 0.5)
plt.plot(BLKdata['time'], BLKdata['alpha_density'], label='Alpha Density', linewidth = 0.5)

# Plot CME times as vertical lines
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")

# Formatting
plt.xlabel("Time")
plt.ylabel("Number Density [#/cm³]")

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 5)) 

# Plot number density
plt.plot(BLKdata['time'], BLKdata['proton_bulk_speed'], label='Proton Bulk Speed', linewidth = 0.5)
plt.plot(BLKdata['time'], BLKdata['alpha_bulk_speed'], label='Alpha Bulk Speed', linewidth = 0.5)

# Plot CME times as vertical lines
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")

# Formatting
plt.xlabel("Time")
plt.ylabel("Speed [km/s]")

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 5)) 

# Plot number density
plt.plot(BLKdata['time'], BLKdata['proton_thermal'], label='Proton Thermal', linewidth = 0.5)
plt.plot(BLKdata['time'], BLKdata['alpha_thermal'], label='Alpha Thermal', linewidth = 0.5)

# Plot CME times as vertical lines
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")

# Formatting
plt.xlabel("Time")
plt.ylabel("Thermal speed [Km/sec]")

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 5)) 
plt.plot(BLKdata['time'], BLKdata['proton_xvelocity'], label='Proton X-velocity', linewidth = 0.5)
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")
plt.xlabel("Time")
plt.ylabel("Speed [km/s]")
plt.show()

plt.figure(figsize=(20, 5)) 
plt.plot(BLKdata['time'], BLKdata['proton_yvelocity'], label='Proton Y-velocity', linewidth = 0.5)
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")
plt.xlabel("Time")
plt.ylabel("Speed [km/s]")
plt.show()

plt.figure(figsize=(20, 5)) 
plt.plot(BLKdata['time'], BLKdata['proton_zvelocity'], label='Proton Z-velocity', linewidth = 0.5)
for idx, t in enumerate(filtered_cme_times):
    plt.axvline(x=t, color='red', linestyle='--', linewidth=0.8, label="CME Event" if idx == 0 else "")
plt.xlabel("Time")
plt.ylabel("Speed [km/s]")
plt.show()
